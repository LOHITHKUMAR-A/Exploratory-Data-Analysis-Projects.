# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\LOHITH KUMAR A\OneDrive\Desktop\workshops\GL Eda hindi\GL EDA ipl\matches.csv")
data
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.info
# Out:
# <bound method DataFrame.info of         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail()
# Out:
#         id    Season           city        date                  team1  \
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
data.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
Seasons=data['Season'].value_counts()
Seasons
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
a=Seasons.keys()
a
# Out:
# Index(['IPL-2013', 'IPL-2012', 'IPL-2011', 'IPL-2010', 'IPL-2014', 'IPL-2016',
#        'IPL-2018', 'IPL-2019', 'IPL-2017', 'IPL-2015', 'IPL-2008', 'IPL-2009'],
#       dtype='object')

# %%
b=data['Season'].value_counts()

# %%
plt.figure(figsize=(10,5))
plt.bar(a,b,color='b')
plt.title("Year vs Number of matches")
plt.xlabel("Year")
plt.ylabel("Number of matches.")
plt.show()

# %%
Matches_hosted_city=data['city'].value_counts()[0:10]
Matches_hosted_city
# Out:
# Mumbai        101
# Kolkata        77
# Delhi          74
# Bangalore      66
# Hyderabad      64
# Chennai        57
# Jaipur         47
# Chandigarh     46
# Pune           38
# Durban         15
# Name: city, dtype: int64

# %%
np.sum(data['toss_winner']==data['winner'])
# Out:
# 393

# %%
Perc_Matches_won_after_tosswin=393/756*100
Perc_Matches_won_after_tosswin
# Out:
# 51.98412698412699

# %%
n=data['player_of_match'].value_counts()[0:6]
n
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# Name: player_of_match, dtype: int64

# %%
m=data['player_of_match'].value_counts().keys()[0:6]
m
# Out:
# Index(['CH Gayle', 'AB de Villiers', 'RG Sharma', 'MS Dhoni', 'DA Warner',
#        'YK Pathan'],
#       dtype='object')

# %%
plt.bar(m,n)
plt.title("Players vs Player of match awards")
# Out:
# Text(0.5, 1.0, 'Players vs Player of match awards')

# %%
r=data["result"].value_counts()
r
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
plt.pie(r,labels=r.keys(),autopct="%0.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x27de8e3cf70>,
# ...
#  [Text(-1.0983952786770845, 0.059395385173346235, 'normal'),
#   Text(1.0972563065182481, -0.07764404552785949, 'tie'),
#   Text(1.0998480408648454, -0.01828351732466672, 'no result')],
#  [Text(-0.5991246974602278, 0.03239748282182522, '98.3%'),
#   Text(0.5985034399190444, -0.042351297560650626, '1.2%'),
#   Text(0.5999171131990065, -0.009972827631636393, '0.5%')])

# %%
Tosswin_teamwise=data["toss_winner"].value_counts()
Tosswin_teamwise
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
data.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
batting_second=data[data['win_by_wickets']!=0]
batting_second
# Out:
#         id    Season           city        date                   team1  \
# 1        2  IPL-2017           Pune  06-04-2017          Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017           Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017  Rising Pune Supergiant
# 5        6  IPL-2017      Hyderabad  09-04-2017           Gujarat Lions
# 6        7  IPL-2017         Mumbai  09-04-2017   Kolkata Knight Riders
# ..     ...       ...            ...         ...                     ...
# 750  11346  IPL-2019         Mohali  05-05-2019     Chennai Super Kings
# 751  11347  IPL-2019         Mumbai  05-05-2019   Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019     Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019     Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
plt.hist(batting_second["win_by_wickets"],bins=30)
plt.title("Number of wickets vs No of matches won")
# Out:
# Text(0.5, 1.0, 'Number of wickets vs No of matches won')

# %%
bsw=batting_second["winner"].value_counts()
bsw
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Kings XI Punjab                42
# Delhi Daredevils               42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
k=bsw.keys()[0:6]
v=batting_second["winner"].value_counts()[0:6]

# %%
plt.figure(figsize=(12,3))
plt.bar(k,v,color="y")
plt.title("Team vs Matches won")
plt.xlabel("Team")
plt.ylabel("Matches")
# Out:
# Text(0, 0.5, 'Matches')

# %%
plt.pie(list(bsw),labels=list(bsw.keys()),autopct="%0.1f%%")
plt.title("Percentage of matches won batting second")
# Out:
# Text(0.5, 1.0, 'Percentage of matches won batting second')

# %%
batting_first=data[data['win_by_runs']!=0]
batting_first
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338  IPL-2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
batting_first["winner"].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.bar(list(batting_first["winner"].value_counts().keys()[0:6]),list(batting_first["winner"].value_counts()[0:6]),color=["blue","yellow","violet","purple","red","orange"])
plt.title("Top 6 teams batting first")
# Out:
# Text(0.5, 1.0, 'Top 6 teams batting first')

# %%
plt.pie(list(batting_first["winner"].value_counts()),labels=list(batting_first["winner"].value_counts().keys()),autopct="%0.1f%%")
plt.title("Percentage of matches won batting first")
# Out:
# Text(0.5, 1.0, 'Percentage of matches won batting first')
