# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\LOHITH KUMAR A\OneDrive\Desktop\workshops\players_20.csv")
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
data.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
data.shape
# Out:
# (18278, 104)

# %%
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
data.isnull().any()
# Out:
# sofifa_id     False
# player_url    False
# short_name    False
# long_name     False
# age           False
#               ...
# lb             True
# lcb            True
# cb             True
# rcb            True
# rb             True
# Length: 104, dtype: bool

# %%
data.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
for col in data.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
data['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
x=data['nationality'].value_counts().head().keys()
x
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
y=data['nationality'].value_counts().head()
y
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(6,5))
plt.bar(x,y,color=["green","blue","pink","violet","brown","yellow"])
plt.title("Country vs Number of Players")
plt.xlabel("Country")
plt.ylabel("Number of Players")
plt.grid(False)
plt.show()

# %%
Top10_tallplayers=data.sort_values(by="height_cm",ascending=False).head(10)

Top10_tallplayers
# Out:
#        sofifa_id                                         player_url  \
# 9208      199321  https://sofifa.com/player/199321/tomas-holy/20...
# 8200      225050  https://sofifa.com/player/225050/abdoul-ba/20/...
# 12808     215408  https://sofifa.com/player/215408/aaron-chapman...
# 3121      192613  https://sofifa.com/player/192613/costel-pantil...
# 12864     237015  https://sofifa.com/player/237015/mikkel-mena-q...
# 17365     241870  https://sofifa.com/player/241870/matt-casey/20...
# 5451      199074  https://sofifa.com/player/199074/lacina-traore...
# 17149     243387  https://sofifa.com/player/243387/samuel-brolin...
# 4868      224836  https://sofifa.com/player/224836/vanja-milinko...
# 7725      243675  https://sofifa.com/player/243675/kjell-scherpe...
#
#                 short_name               long_name  age         dob  \
# 9208               T. Holý              Tomáš Holý   27  1991-12-10
# 8200                 A. Ba               Abdoul Ba   25  1994-02-08
# ...

# %%
Top10_tallplayers[['short_name',"height_cm"]]
# Out:
#                 short_name  height_cm
# 9208               T. Holý        205
# 8200                 A. Ba        203
# 12808           A. Chapman        203
# 3121         C. Pantilimon        203
# 12864             M. Qvist        203
# 17365             M. Casey        203
# 5451             L. Traoré        203
# 17149            S. Brolin        202
# 4868   V. Milinković-Savić        202
# 7725           K. Scherpen        202

# %%
Top5_Weighedplayers=data[["short_name","weight_kg"]].sort_values(by="weight_kg",ascending=False).head(10)
Top5_Weighedplayers
# Out:
#           short_name  weight_kg
# 10693   A. Akinfenwa        110
# 9572        C. Seitz        107
# 15064       E. Louro        104
# 7439     F. Farnolle        104
# 13576   L. Watkowiak        103
# 11945  D. Telgenkamp        103
# 1389   L. Unnerstall        103
# 11561    E. Johansen        102
# 9208         T. Holý        102
# 2278        B. Hamid        102

# %%
Nation=data["nationality"].value_counts().head(10)
Nation
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
a=Nation.keys()

# %%
wage=data[["short_name","wage_eur"]].sort_values(by="wage_eur",ascending=False).head(10)
wage
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 17          S. Agüero    300000
# 21    Sergio Busquets    300000

# %%
a=wage["short_name"]
b=wage["wage_eur"]

# %%
plt.figure(figsize=(15,5))
plt.bar(a,b,color="b")
plt.title("Top 10 players with highest Salary")
plt.xlabel("Player name")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
sh=data[["short_name","shooting"]].sort_values(by="shooting",ascending=False).head(6)
sh
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0
# 19           L. Suárez      89.0

# %%
data['nationality']=='Spain'
Spain=data[data['nationality']=='Spain']
Spain
# Out:
#        sofifa_id                                         player_url  \
# 14        193080  https://sofifa.com/player/193080/david-de-gea-...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 21        189511  https://sofifa.com/player/189511/sergio-busque...
# 29        152729  https://sofifa.com/player/152729/gerard-pique-...
# 33        168542  https://sofifa.com/player/168542/david-josue-j...
# ...          ...                                                ...
# 16936     251653  https://sofifa.com/player/251653/jon-irazabal-...
# 17006     220190  https://sofifa.com/player/220190/cristian-arco...
# 17355     245787  https://sofifa.com/player/245787/ivan-martinez...
# 17912     244559  https://sofifa.com/player/244559/carlos-mendes...
# 17936     251814  https://sofifa.com/player/251814/angel-fraga-c...
#
#                 short_name                  long_name  age         dob  \
# 14                  De Gea      David De Gea Quintana   28  1990-11-07
# ...

# %%
S_wage=Spain[["short_name","wage_eur"]].sort_values(by="wage_eur",ascending=False).head(10)
S_wage
# Out:
#           short_name  wage_eur
# 18      Sergio Ramos    300000
# 21   Sergio Busquets    300000
# 29             Piqué    285000
# 33       David Silva    265000
# 62              Isco    245000
# 51        Jordi Alba    240000
# 14            De Gea    205000
# 94          Carvajal    205000
# 52            Thiago    180000
# 403    Lucas Vázquez    180000

# %%
Sp=Spain.groupby(by='club',axis=0,sort=True)

# %%
for club in Sp:
    print(club)
#     print(club_Sp)
# Out:
# ('1. FC Köln',       sofifa_id                                         player_url  \
# 1005     223033  https://sofifa.com/player/223033/jorge-mere-pe...
#
#       short_name         long_name  age         dob  height_cm  weight_kg  \
# 1005  Jorge Meré  Jorge Meré Pérez   22  1997-04-17        182         80
#
#      nationality        club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 1005       Spain  1. FC Köln  ...  68+2  73+2  73+2  73+2  68+2  70+2  76+2
#
#         cb   rcb    rb
# 1005  76+2  76+2  70+2
#
# [1 rows x 104 columns])
# ('1. FC Nürnberg',       sofifa_id                                         player_url  \
# 8066     223095  https://sofifa.com/player/223095/federico-pala...
#
#                 short_name                   long_name  age         dob  \
# 8066  F. Palacios Martínez  Federico Palacios Martínez   24  1995-04-09
#
#       height_cm  weight_kg nationality            club  ...   lwb   ldm   cdm  \
# ...

# %%
Spw=Sp.max("wage_eur").head(10)
Spw
# Out:
#                   sofifa_id  age  height_cm  weight_kg  overall  potential  \
# club
# 1. FC Köln           223033   22        182         80       77         85
# 1. FC Nürnberg       223095   24        170         68       67         72
# 1. FSV Mainz 05      236295   22        178         68       78         84
# AD Alcorcón          252723   36        190         85       72         77
# AEK Athens           201991   28        187         73       71         72
# AS Monaco            162895   32        179         77       81         81
# AS Saint-Étienne     228321   23        168         67       72         79
# Al Hilal             191688   33        189         96       75         75
# Alanyaspor           188135   30        180         69       74         74
# Albacete BP          252400   34        191         82       73         79
#
#                   value_eur  wage_eur  international_reputation  weak_foot  \
# club
# ...
